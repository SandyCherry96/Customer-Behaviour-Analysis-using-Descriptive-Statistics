# %% [markdown]
# <a href="https://colab.research.google.com/github/SandyCherry96/Customer-Behaviour-Analysis-using-Descriptive-Statistics/blob/main/Applied_Statistics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# Read the file
superstore_data_path = "C:\\Users\\sanrkin\\Downloads\\Superstore Marketing Data - Sheet1.csv"
superstore_dataframe = pd.read_csv(superstore_data_path)
superstore_dataframe
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# # Dataset Description

# %% [markdown]
# # Exploring data

# %%
# Read first 5 rows
superstore_dataframe.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# Read last 5 rows
superstore_dataframe.tail(5)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
# Columns of dataset
superstore_dataframe.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
# Shape of Dataframe
superstore_dataframe.shape
# Out:
# (2240, 22)

# %% [markdown]
# # Handling missing values

# %%
# Check the null values
null_counts = superstore_dataframe.isnull().sum()
print(null_counts)
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# Counting number of unwanated string in the column
missing_date = superstore_dataframe["Dt_Customer"] == "########"
print(missing_date.sum())
# Out:
# 916

# %%
# Replace '########' with NaN in the 'Dt_Customer' column

superstore_dataframe["Dt_Customer"] = superstore_dataframe["Dt_Customer"].replace("########",np.nan)

# %%
superstore_dataframe
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
# check the null values
null_count1 = print(superstore_dataframe.isnull().sum())
print(null_count1)
# Out:
# Id                       0
# Year_Birth               0
# Education                0
# Marital_Status           0
# Income                  24
# Kidhome                  0
# Teenhome                 0
# Dt_Customer            916
# Recency                  0
# MntWines                 0
# MntFruits                0
# MntMeatProducts          0
# MntFishProducts          0
# MntSweetProducts         0
# MntGoldProds             0
# NumDealsPurchases        0
# NumWebPurchases          0
# NumCatalogPurchases      0
# NumStorePurchases        0
# NumWebVisitsMonth        0
# Response                 0
# Complain                 0
# dtype: int64
# None

# %%
# Null percentage
null_percentage = superstore_dataframe.isnull().sum()/len(superstore_dataframe) * 100
null_percentage_df = pd.DataFrame({'Null percentage':null_percentage})
null_percentage_df
# Out:
#                      Null percentage
# Id                          0.000000
# Year_Birth                  0.000000
# Education                   0.000000
# Marital_Status              0.000000
# Income                      1.071429
# Kidhome                     0.000000
# Teenhome                    0.000000
# Dt_Customer                40.892857
# Recency                     0.000000
# MntWines                    0.000000
# MntFruits                   0.000000
# MntMeatProducts             0.000000
# MntFishProducts             0.000000
# MntSweetProducts            0.000000
# MntGoldProds                0.000000
# NumDealsPurchases           0.000000
# NumWebPurchases             0.000000
# NumCatalogPurchases         0.000000
# NumStorePurchases           0.000000
# NumWebVisitsMonth           0.000000
# Response                    0.000000
# Complain                    0.000000

# %% [markdown]
# We can see that the column 'Dt_Customer' has 40% missing data, which is the date has not been updated, so i will drop the column as the major chunk of the data is missing.

# %%
# Drop the dt_customer column
superstore_dataframe.drop(columns='Dt_Customer',inplace=True)

# %%
# Read the dataset
superstore_dataframe
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome  Recency  MntWines  MntFruits  ...  MntFishProducts  \
# 0            0        0       189        104  ...              111
# ...

# %% [markdown]
# # Analyzing Income column

# %%
superstore_dataframe.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
# identify the outliers in income
plt.figure(figsize=(8,6))
sns.distplot(superstore_dataframe['Income'])
plt.title('Boxplot of Income')
plt.xlabel('Income')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\4293391689.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(superstore_dataframe['Income'])

# %% [markdown]
# It shows that the DataFrame contains outliers. When dealing with outliers, it is recommended to use the median to fill missing values.

# %%
# Fill NaN values in the 'Income' column with the median of that column
median_income = superstore_dataframe['Income'].median()
superstore_dataframe.fillna(median_income,inplace=True)

# %%
# Calculate the first and third quartiles
Q1 = superstore_dataframe['Income'].quantile(0.25)
Q3 = superstore_dataframe['Income'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = superstore_dataframe[(superstore_dataframe['Income'] < lower_bound) | (superstore_dataframe['Income'] > upper_bound)]
print(len(outliers))
# Out:
# 8

# %% [markdown]
# Any data points below the lower bound or above the upper bound are considered outliers. The factor of 1.5 is commonly used to determine outliers based on the IQR method.

# %%
# Remove outliers
df_no_outliers = superstore_dataframe[(superstore_dataframe['Income'] >= lower_bound) & (superstore_dataframe['Income'] <= upper_bound)]
print(df_no_outliers)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome  Recency  MntWines  MntFruits  ...  MntFishProducts  \
# 0            0        0       189        104  ...              111
# ...

# %%
# identify the outliers in income
plt.figure(figsize=(8,6))
sns.boxplot(data=df_no_outliers,x='Income')
plt.title('Boxplot of Income')
plt.xlabel('Income')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# check the datatypes
superstore_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Recency              2240 non-null   int64
#  8   MntWines             2240 non-null   int64
#  9   MntFruits            2240 non-null   int64
#  10  MntMeatProducts      2240 non-null   int64
#  11  MntFishProducts      2240 non-null   int64
#  12  MntSweetProducts     2240 non-null   int64
#  13  MntGoldProds         2240 non-null   int64
#  14  NumDealsPurchases    2240 non-null   int64
# ...

# %%
numerical_columns = superstore_dataframe.select_dtypes(include=['float64', 'int64']).columns
stats_df = pd.DataFrame(index=numerical_columns)
stats_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [Id, Year_Birth, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain]

# %%
stats_df['Mean'] = df_no_outliers[numerical_columns].mean()
stats_df['Median'] = df_no_outliers[numerical_columns].median()
stats_df['Variance'] = df_no_outliers[numerical_columns].var()
stats_df['Standard Deviation'] = df_no_outliers[numerical_columns].std()

# Print the statistics DataFrame
print(stats_df)
# Out:
#                              Mean   Median      Variance  Standard Deviation
# Id                    5590.736559   5458.5  1.053905e+07         3246.390817
# Year_Birth            1968.792563   1970.0  1.437682e+02           11.990340
# Income               51630.926971  51381.5  4.244292e+08        20601.679542
# Kidhome                  0.444444      0.0  2.900543e-01            0.538567
# Teenhome                 0.507168      0.0  2.966765e-01            0.544680
# Recency                 49.111111     49.0  8.382700e+02           28.952893
# MntWines               304.930108    176.0  1.134241e+05          336.784950
# MntFruits               26.380376      8.0  1.585754e+03           39.821532
# MntMeatProducts        165.319444     67.0  4.813699e+04          219.401447
# MntFishProducts         37.644713     12.0  2.990942e+03           54.689504
# MntSweetProducts        27.155466      8.0  1.707790e+03           41.325414
# ...

# %% [markdown]
# Visualizing the distribution of customer demographics including age, education, and marital status using histograms and bar charts

# %%
# create a histogram using Seaborn
plt.figure(figsize=(8,6))
sns.histplot(df_no_outliers['Year_Birth'],bins = 20,kde=True,color='blue',edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y',alpha = 0.75)
plt.show()

# %% [markdown]
# If the bulk of the bars are on the left side and the tail extends more on the right,
# it indicates a positive skew.

# %%
# create a count plot for Education using seaborn
plt.figure(figsize=(8, 6))
sns.countplot(data=df_no_outliers, x='Education', palette='viridis')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\252713504.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_no_outliers, x='Education', palette='viridis')

# %%
# Create a count plot for Martial using seaborn
plt.figure(figsize=(8,6))
sns.countplot(data=df_no_outliers,x='Marital_Status',palette='viridis')
plt.title('Distribution of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.grid(axis='y',alpha=0.7)
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\3799049818.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_no_outliers,x='Marital_Status',palette='viridis')

# %% [markdown]
# Analysis of Customer Demographics
# Age Distribution (Histogram)
# Interpretation:
#
# The histogram represents the distribution of customer ages based on birth year.
# Provides an overview of age spread and concentration within the dataset.
# Observations:
#
# The distribution appears to be relatively normal or slightly right-skewed.
# Dominant customer segments within specific age ranges might be identifiable.
# Education Distribution (Bar Chart)
# Interpretation:
#
# The bar chart displays the frequency of customers in different education levels.
# Visualizes the relative proportions of customers across educational backgrounds.
# Observations:
#
# Graduated custoers prevalent highest education levels among customers based on the tallest bars.
# Shows the diversity in educational backgrounds within the customer base.
# Marital Status Distribution (Bar Chart)
# Interpretation:
#
# The bar chart illustrates the distribution of customers across various marital statuses.
# Helps in understanding the prevalence of different marital statuses among customers.
# Observations:
#
# Highlights the dominant marital status category among the customer base are the married people.
# Provides insights into the relative distribution across different marital statuses.
# Overall Insights and Actionable Points
# Understanding Customer Demographics:
#
# Helps in targeted marketing strategies based on age groups, educational backgrounds, and marital statuses.
# Tailored Marketing and Offers:
#
# Customizing campaigns or products to match the preferences of specific demographic segments identified.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
# measures of central tendency (mean, median) and measures of dispersion (variance, standard deviation)
stats_df
# Out:
#                              Mean   Median      Variance  Standard Deviation
# Id                    5590.736559   5458.5  1.053905e+07         3246.390817
# Year_Birth            1968.792563   1970.0  1.437682e+02           11.990340
# Income               51630.926971  51381.5  4.244292e+08        20601.679542
# Kidhome                  0.444444      0.0  2.900543e-01            0.538567
# Teenhome                 0.507168      0.0  2.966765e-01            0.544680
# Recency                 49.111111     49.0  8.382700e+02           28.952893
# MntWines               304.930108    176.0  1.134241e+05          336.784950
# MntFruits               26.380376      8.0  1.585754e+03           39.821532
# MntMeatProducts        165.319444     67.0  4.813699e+04          219.401447
# MntFishProducts         37.644713     12.0  2.990942e+03           54.689504
# MntSweetProducts        27.155466      8.0  1.707790e+03           41.325414
# ...

# %%
# numerical_columns
numerical_columns
# Out:
# Index(['Id', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Response', 'Complain'],
#       dtype='object')

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 12), constrained_layout=True)
axes = axes.flatten()

# Plot each column in a subplot
for i, column in enumerate(numerical_columns[:9]):
    sns.boxplot(x=df_no_outliers[column], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column}')
    axes[i].set_xlabel(column)
    axes[i].grid(axis='y', alpha=0.75)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\530099638.py:11: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
for column in numerical_columns:
    Q1 = superstore_dataframe[column].quantile(0.25)
    Q3 = superstore_dataframe[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove outliers
    superstore_dataframe = superstore_dataframe[(superstore_dataframe[column] >= lower_bound) & (superstore_dataframe[column] <= upper_bound)]

fig, axes = plt.subplots(5, 3, figsize=(18, 12), constrained_layout=True)
axes = axes.flatten()

# Plotting the boxplots
for i, column in enumerate(numerical_columns):
    sns.boxplot(x=superstore_dataframe[column], ax=axes[i])
    axes[i].set_title(f'Boxplot of {column} After Outlier Removal')
    axes[i].set_ylabel(column)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 18
#      16 # Plotting the boxplots
#      17 for i, column in enumerate(numerical_columns):
# ---> 18     sns.boxplot(x=superstore_dataframe[column], ax=axes[i])
#      19     axes[i].set_title(f'Boxplot of {column} After Outlier Removal')
#      20     axes[i].set_ylabel(column)
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# # Recency: This variable could follow an Exponential distribution as it measures the time since the last purchase.

# %%
import matplotlib.pyplot as plt

# Step 1: Visualize the Recency variable
recency_data = df_no_outliers['Recency'].dropna()

plt.hist(recency_data, bins=30, density=True, alpha=0.6, color='g')
plt.title('Recency Histogram')
plt.xlabel('Recency (days)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# From the plot, it's clear that the Exponential distribution doesn't fit the Recency data well, as the actual data (in green) appears more uniformly spread. This visual reinforces that we should test other distributions, especially Uniform, which may be more suitable

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Step 1: Fit a Uniform distribution to the data
min_val = recency_data.min()
max_val = recency_data.max()

# Step 2: Generate the x values and Uniform PDF based on the fitted distribution
x = np.linspace(min_val, max_val, 1000)
pdf_uniform = stats.uniform.pdf(x, loc=min_val, scale=max_val - min_val)


# Step 3: Plot the Recency data histogram and the fitted Uniform distribution
plt.hist(recency_data, bins=30, density=True, alpha=0.6, color='g', label='Recency Data')
plt.plot(x, pdf_uniform, 'b-', lw=2, label='Uniform fit')

plt.title('Recency Data with Uniform Fit')
plt.xlabel('Recency (days)')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# In the data, the column "Response" seems to be the binary variable representing whether a customer responded to the marketing campaign, where:
#
# 1 likely indicates a response.
# 0 likely indicates no response.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

prob_response = df_no_outliers['Response'].mean()

prob_success = stats.bernoulli.pmf(1, prob_response)
print(f"Probability of Response = 1 (success): {prob_success:.4f}")

expected_value = stats.bernoulli.mean(prob_response)
print(f"Expected value (mean) for Response: {expected_value:.4f}")

# Visualize the Bernoulli distribution
outcomes = [0, 1]
pmf_values = stats.bernoulli.pmf(outcomes, prob_response)

plt.bar(outcomes, pmf_values, align='center', alpha=0.5)
plt.xticks(outcomes)
plt.xlabel('Response')
plt.ylabel('Probability')
plt.title('Bernoulli Distribution for Response')
plt.show()
# Out:
# Probability of Response = 1 (success): 0.1496
# Expected value (mean) for Response: 0.1496

# %%
# NumDealsPurchases represents the count of purchases made over a certain time period and
# these purchases occur independently with a constant average rate,
# the Poisson distribution would be a suitable model for this variable.

# %%
lambda_value = df_no_outliers['NumDealsPurchases'].mean()
print(f"Average number of deals purchased (lambda): {lambda_value:.2f}")

# Calculate the Poisson PMF for a range of possible deal purchases
k_values = np.arange(0, 10)  # Possible values (0 to 9 deals purchased)
pmf_values = stats.poisson.pmf(k_values, lambda_value)

# Create a bar plot for the Poisson distribution
plt.figure(figsize=(8, 6))
plt.bar(k_values, pmf_values, color='lightgreen', alpha=0.7, edgecolor='black')

# Customize plot aesthetics
plt.xticks(k_values)
plt.xlabel('Number of Deals Purchased', fontsize=14)
plt.ylabel('Probability', fontsize=14)
plt.title('Poisson Distribution of Number of Deals Purchased', fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, max(pmf_values) * 1.1)  # Set y-axis limit

# Show the plot
plt.show()
# Out:
# Average number of deals purchased (lambda): 2.32

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
numeric_df = df_no_outliers.select_dtypes(include=['float64', 'int64'])


corr_matrix = numeric_df.corr()


plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# %% [markdown]
# Key insights regarding variables:
# 1. Income and Spending Patterns:
# There seems to be a positive correlation between 'Income' and spending on 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumWebPurchases', 'NumCatalogPurchases'and 'NumStorePurchases'. Higher-income customers tend to spend more on these categories.
#
# 2. 'Kidhome' and 'NumWebVisitsMonth' (correlation = 0.45):
# A correlation of 0.45 indicates a moderate positive correlation between the number of children at home ('Kidhome') and the number of web visits per month ('NumWebVisitsMonth').
# This suggests that customers with more children at home are moderately more likely to make a higher number of web visits each month. The positive correlation implies that as the number of children at home increases, the number of web visits tends to increase as well.
#
#
# 3. 'Teenhome' and 'NumDealsPurchases':
# A correlation of 0.40 between 'Teenhome' and 'NumDealsPurchases' indicates a moderate positive association, suggesting that customers with more teenagers at home tend to have a higher number of deals purchases.
#
# 4. 'NumDealsPurchases' and 'NumWebPurchases' (correlation = 0.25):
# A correlation of 0.25 indicates a positive, but relatively weak, correlation between the number of deals purchases ('NumDealsPurchases') and the number of web purchases ('NumWebPurchases').
# This suggests that customers who engage in more deals purchases are somewhat more likely to make more web-based purchases. However, the correlation is not very strong, and other factors may also influence the relationship.
#
#     'NumDealsPurchases' and 'NumWebVisitsMonth' (correlation = 0.37):
#     A correlation of 0.37 indicates a positive, moderate correlation between the number of deals purchases ('NumDealsPurchases') and the number of web visits per month ('NumWebVisitsMonth').
#     This suggests that customers who make a higher number of deals purchases are moderately more likely to have a higher number of web visits each month. The positive correlation implies that as the number of deals purchases increases, the number of web visits tends to increase as well.
#
#
# 5. 'NumWebPurchases' and 'Income' (correlation = 0.49):
# A correlation of 0.49 indicates a moderate positive correlation between the number of web purchases ('NumWebPurchases') and the income of customers ('Income').
# This suggests that customers with higher incomes tend to make a higher number of web-based purchases. The positive correlation implies that as income increases, the number of web purchases also tends to increase.
#
#     'NumWebPurchases' and 'MntWines' (correlation = 0.54):
#     A correlation of 0.54 indicates a moderate to strong positive correlation between the number of web purchases ('NumWebPurchases') and spending on wines ('MntWines').
#     This implies that customers who make a higher number of web purchases are also likely to spend more on wines, fruits, meat, fish products, sweetproducts, gold products. The positive correlation suggests a concurrent increase in both variables.
#     Peolple who purchase through web also tend to take more deals on purchases.
#
#     'NumWebPurchases' and 'NumCatalogPurchases' (correlation = 0.41):
#     A correlation of 0.41 indicates a moderate positive correlation between the number of web purchases ('NumWebPurchases') and the number of catalog purchases ('NumCatalogPurchases').
#     This suggests that customers who make more web purchases also tend to make a moderately higher number of catalog purchases. The positive correlation implies a tendency for these two variables to increase together.
#
#     'NumWebPurchases' and 'NumStorePurchases' (correlation = 0.50):
#     A correlation of 0.50 indicates a moderate positive correlation between the number of web purchases ('NumWebPurchases') and the number of store purchases ('NumStorePurchases').
#     This suggests that customers who make more web purchases are also likely to make a moderately higher number of in-store purchases. The positive correlation implies a concurrent increase in both variables.

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# 1. Targeted Marketing Campaigns:
# Identify high-value customer segments and design targeted marketing campaigns to cater to their specific needs and preferences.

# %%
# Calculate average income for each marital status category
avg_income_by_marital_status = df_no_outliers.groupby('Marital_Status')['Income'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='Marital_Status', y='Income', data=avg_income_by_marital_status, palette='viridis')
plt.title('Average Income by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Average Income')
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\23070316.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Marital_Status', y='Income', data=avg_income_by_marital_status, palette='viridis')

# %% [markdown]
# 2. Web pruchases v/s store purchases:

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.countplot(x='NumWebPurchases', data=df_no_outliers, color='skyblue')
plt.title('Number of Web Purchases')

plt.subplot(1, 2, 2)
sns.countplot(x='NumStorePurchases', data=df_no_outliers, color='salmon')
plt.title('Number of Store Purchases')

plt.tight_layout()
plt.show()

# Scatter Plot for Correlation Analysis
plt.figure(figsize=(8, 6))
sns.scatterplot(x='NumWebVisitsMonth', y='NumWebPurchases', data=df_no_outliers, color='green')
plt.title('Correlation between Web Visits and Web Purchases')
plt.xlabel('Number of Web Visits in Last Month')
plt.ylabel('Number of Web Purchases')
plt.show()

# %% [markdown]
# 3. Promotions and Deals:

# %%
selected_columns = ['Income', 'NumDealsPurchases']

# Select relevant columns
df_selected = df_no_outliers[selected_columns]

plt.figure(figsize=(8, 6))
sns.boxplot(x='NumDealsPurchases', y='Income', data=df_selected, palette='viridis')
plt.title('Distribution of Income for Customers with Deals Purchases')
plt.xlabel('Number of Deals Purchases')
plt.ylabel('Income')
plt.show()
# Out:
# C:\Users\sanrkin\AppData\Local\Temp\ipykernel_23108\3488658720.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='NumDealsPurchases', y='Income', data=df_selected, palette='viridis')

# %% [markdown]
# 4. Segment-Specific Communication

# %%
selected_columns = ['Kidhome', 'Teenhome']

# Select relevant columns
df_selected = df_no_outliers[selected_columns]

# Count plot for family structure
plt.figure(figsize=(6, 6))
sns.countplot(x='Kidhome', data=df_selected, hue='Teenhome', palette='coolwarm')
plt.title('Family Structure: Customers with Kidhome and Teenhome')
plt.xlabel('Presence of Kidhome')
plt.ylabel('Count')
plt.legend(title='Presence of Teenhome', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Insights from the visualization:
#
# Family Structure Distribution:
#
# The count plot displays the distribution of customers based on the presence of 'Kidhome' and 'Teenhome'.
# Different colors represent the presence or absence of 'Teenhome' within each category of 'Kidhome'.
# Communication Strategy Insights:
#
# If there are distinct segments with families having both 'Kidhome' and 'Teenhome', it indicates a unique customer segment with specific communication needs.
# By understanding the composition of your customer base in terms of family structure, you can tailor communication strategies to address the preferences and needs of different segments.
# Targeted Messaging:
#
# Consider crafting targeted messages for families with both 'Kidhome' and 'Teenhome' that resonate with their specific interests and challenges.
# Communication strategies for customers without children may focus on different aspects that align with their lifestyle and preferences.
# Personalized Offers:
#
# Use this information to personalize offers or promotions that cater to the needs of specific family segments, enhancing the effectiveness of your marketing campaigns.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
